# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import datetime

# %% [markdown]
# # Taxis December 2015 Data

# %%
yellow_taxi_2015_12 = "../clean_csvs/taxi_dec_2015.csv"
yt_dec_2015_df = pd.read_csv(yellow_taxi_2015_12)
yt_dec_2015_df.head()
# Out:
#    Unnamed: 0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           9  2015-12-01 00:00:04   2015-12-01 00:10:43                2
# 1          12  2015-12-01 00:00:05   2015-12-01 00:05:51                1
# 2          13  2015-12-01 00:00:05   2015-12-02 00:00:00                1
# 3          36  2015-12-01 00:00:13   2015-12-01 00:05:40                1
# 4          44  2015-12-01 00:00:16   2015-12-01 00:03:40                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.42        -73.999634        40.734772           1
# 1           1.00        -73.995766        40.743790           1
# 2           0.94        -74.005417        40.727283           1
# 3           0.99        -73.996536        40.726871           1
# 4           0.60        -73.979546        40.727444           1
#
#    dropoff_longitude  dropoff_latitude  fare_amount  tip_amount  total_amount  \
# ...

# %%
#yt_dec_2015_df.count()

# %%
# Taxi Pick-ups for December 2015
# Identify 4 different times of day and count the number of for vehicle rides that occur in each 6 hour interval
# yt_dec_2015_df

yt_morning_dec_15_df = yt_dec_2015_df.loc[(yt_dec_2015_df['pickup_time'] > '05:00:00') & (yt_dec_2015_df['pickup_time']<='11:00:00')]
yt_dec_morn_count_15 = yt_morning_dec_15_df.shape[0]
#print(yt_dec_morn_count_15)

yt_day_dec_15_df = yt_dec_2015_df.loc[(yt_dec_2015_df['pickup_time'] > '11:00:00') & (yt_dec_2015_df['pickup_time']<='17:00:00')]
yt_dec_day_count_15 = yt_day_dec_15_df.shape[0]
#print(yt_dec_day_count_15)

yt_evening_dec_15_df = yt_dec_2015_df.loc[(yt_dec_2015_df['pickup_time'] > '17:00:00') & (yt_dec_2015_df['pickup_time']<='23:00:00')]
yt_dec_eve_count_15 = yt_evening_dec_15_df.shape[0]
#print(yt_dec_eve_count_15)

yt_late_night_dec_15_df = yt_dec_2015_df.loc[(yt_dec_2015_df['pickup_time'] > '23:00:00')]
yt_dec_ln_count_15 = yt_late_night_dec_15_df.shape[0]

yt_later_night_dec_15_df = yt_dec_2015_df.loc[(yt_dec_2015_df['pickup_time'] <= '05:00:00')]
yt_dec_lrn_count_15 = yt_later_night_dec_15_df.shape[0]

yt_dec_afthrs_count_15 = yt_dec_lrn_count_15 + yt_dec_ln_count_15
#print(yt_dec_afthrs_count_15)

# %% [markdown]
# # Taxis June 2015

# %%
yellow_taxi_2015_06 = "../clean_csvs/taxi_june_2015.csv"
yt_june_2015_df = pd.read_csv(yellow_taxi_2015_06)
yt_june_2015_df.head()
# Out:
#    Unnamed: 0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          20  2015-06-02 11:19:48   2015-06-02 11:34:36                1
# 1          34  2015-06-02 11:19:58   2015-06-02 11:28:29                5
# 2          40  2015-06-02 11:20:02   2015-06-02 11:25:08                1
# 3          43  2015-06-02 11:20:05   2015-06-02 12:02:22                2
# 4          47  2015-06-02 11:20:07   2015-06-02 11:26:40                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           3.90        -73.949623        40.772671           1
# 1           0.85        -74.006416        40.733501           1
# 2           0.80        -73.995033        40.725391           1
# 3           5.30        -73.955170        40.788544           1
# 4           0.99        -73.997749        40.730190           1
#
#    dropoff_longitude  dropoff_latitude  fare_amount  tip_amount  total_amount  \
# ...

# %%
# Taxi Pick-ups for June 2015
# Identify 4 different times of day and count the number of for vehicle rides that occur in each 6 hour interval
# yt_june_2015_df

yt_morning_june_15_df = yt_june_2015_df.loc[(yt_june_2015_df['pickup_time'] > '05:00:00') & (yt_june_2015_df['pickup_time']<='11:00:00')]
yt_june_morn_count_15 = yt_morning_june_15_df.shape[0]
#print(yt_june_morn_count_15)

yt_day_june_15_df = yt_june_2015_df.loc[(yt_june_2015_df['pickup_time'] > '11:00:00') & (yt_june_2015_df['pickup_time']<='17:00:00')]
yt_june_day_count_15 = yt_day_june_15_df.shape[0]
#print(yt_june_day_count_15)

yt_evening_june_15_df = yt_june_2015_df.loc[(yt_june_2015_df['pickup_time'] > '17:00:00') & (yt_june_2015_df['pickup_time']<='23:00:00')]
yt_june_eve_count_15 = yt_evening_june_15_df.shape[0]
#print(yt_june_eve_count_15)

yt_late_night_june_15_df = yt_june_2015_df.loc[(yt_june_2015_df['pickup_time'] > '23:00:00')]
yt_june_ln_count_15 = yt_late_night_june_15_df.shape[0]


yt_later_night_june_15_df = yt_june_2015_df.loc[(yt_june_2015_df['pickup_time'] <= '05:00:00')]
yt_june_lrn_count_15 = yt_later_night_june_15_df.shape[0]

yt_june_afthrs_count_15 = yt_june_lrn_count_15 + yt_june_ln_count_15
#print(yt_june_afthrs_count_15)

# %% [markdown]
# ## For Hire Vehicles June 2015 Data

# %%
for_hire_veh_2015_06 = "../clean_csvs/FHV_june_2015.csv"
fhv_june_2015_df = pd.read_csv(for_hire_veh_2015_06)
fhv_june_2015_df.head()
# Out:
#    Unnamed: 0 Dispatching_base_num          Pickup_date  locationID  \
# 0       61562               B00221  2015-06-03 14:27:00       263.0
# 1       61839               B00221  2015-06-04 08:53:00       263.0
# 2       61961               B00221  2015-06-04 10:51:00       263.0
# 3       62546               B00221  2015-06-05 10:45:00       263.0
# 4       62582               B00221  2015-06-05 11:29:00       263.0
#
#   pickup_date pickup_time
# 0  2015-06-03    14:27:00
# 1  2015-06-04    08:53:00
# 2  2015-06-04    10:51:00
# 3  2015-06-05    10:45:00
# 4  2015-06-05    11:29:00

# %%
#fhv_june_2015_df.count()

# %%
# For Hire Vehicles Pick-ups for June 2015
# Identify 4 different times of day and count the number of for vehicle rides that occur in each 6 hour interval
# fvh_june_2015_df

fhv_morning_june_15_df = fhv_june_2015_df.loc[(fhv_june_2015_df['pickup_time'] > '05:00:00') & (fhv_june_2015_df['pickup_time']<='11:00:00')]
fhv_june_morn_count_15 = fhv_morning_june_15_df.shape[0]

fhv_day_june_15_df = fhv_june_2015_df.loc[(fhv_june_2015_df['pickup_time'] > '11:00:00') & (fhv_june_2015_df['pickup_time']<='17:00:00')]
fhv_june_day_count_15 = fhv_day_june_15_df.shape[0]

fhv_evening_june_15_df = fhv_june_2015_df.loc[(fhv_june_2015_df['pickup_time'] > '17:00:00') & (fhv_june_2015_df['pickup_time']<='23:00:00')]
fhv_june_eve_count_15 = fhv_evening_june_15_df.shape[0]

fhv_late_night_june_15_df = fhv_june_2015_df.loc[(fhv_june_2015_df['pickup_time'] > '23:00:00')]
fhv_june_ln_count_15 = fhv_late_night_june_15_df.shape[0]

fhv_later_night_june_15_df = fhv_june_2015_df.loc[(fhv_june_2015_df['pickup_time'] <= '05:00:00')]
fhv_june_lrn_count_15 = fhv_later_night_june_15_df.shape[0]

fhv_june_afthrs_count_15 = fhv_june_lrn_count_15 + fhv_june_ln_count_15

# %% [markdown]
# ## For Hire Vehicles December 2015 Data

# %%
for_hire_veh_2015_12 ="../clean_csvs/FHV_dec_2015.csv"
fhv_dec_2015_df = pd.read_csv(for_hire_veh_2015_12)
fhv_dec_2015_df.head()
# Out:
#    Unnamed: 0 Dispatching_base_num          Pickup_date  locationID  \
# 0       32289               B00021  2015-12-23 21:44:00       263.0
# 1       93594               B00095  2015-12-30 13:52:00       263.0
# 2      545224              B00559   2015-12-05 09:30:00       263.0
# 3      546763              B00559   2015-12-15 12:06:00       263.0
# 4      713928               B00706  2015-12-22 09:46:00       263.0
#
#   pickup_date pickup_time
# 0  2015-12-23    21:44:00
# 1  2015-12-30    13:52:00
# 2  2015-12-05    09:30:00
# 3  2015-12-15    12:06:00
# 4  2015-12-22    09:46:00

# %%
#fhv_dec_2015_df.count()

# %%
# For Hire Vehicles Pick-ups for December 2015
# Identify 4 different times of day and count the number of for hire rides that occur in each 6 hour interval
# fhv_dec_2015_df

fhv_morning_dec_15_df = fhv_dec_2015_df.loc[(fhv_dec_2015_df['pickup_time'] > '05:00:00') & (fhv_dec_2015_df['pickup_time']<='11:00:00')]
fhv_dec_morn_count_15 = fhv_morning_dec_15_df.shape[0]
#print(fhv_dec_morn_count_15)

fhv_day_dec_15_df = fhv_dec_2015_df.loc[(fhv_dec_2015_df['pickup_time'] > '11:00:00') & (fhv_dec_2015_df['pickup_time']<='17:00:00')]
fhv_dec_day_count_15 = fhv_day_dec_15_df.shape[0]
#print(fhv_dec_day_count_15)

fhv_evening_dec_15_df = fhv_dec_2015_df.loc[(fhv_dec_2015_df['pickup_time'] > '17:00:00') & (fhv_dec_2015_df['pickup_time']<='23:00:00')]
fhv_dec_eve_count_15 = fhv_evening_dec_15_df.shape[0]
#print(fhv_dec_eve_count_15)

fhv_late_night_dec_15_df = fhv_dec_2015_df.loc[(fhv_dec_2015_df['pickup_time'] > '23:00:00')]
fhv_dec_ln_count_15 = fhv_late_night_dec_15_df.shape[0]

fhv_later_night_dec_15_df = fhv_dec_2015_df.loc[(fhv_dec_2015_df['pickup_time'] <= '05:00:00')]
fhv_dec_lrn_count_15 = fhv_later_night_dec_15_df.shape[0]

fhv_dec_afthrs_count_15 = fhv_dec_lrn_count_15 + fhv_dec_ln_count_15
#print(fhv_dec_afthrs_count_15)

# %%
# Plot bar chart for for hire vehicles to compare number of rides in December & June of 2015

Dec_2015 = [fhv_dec_morn_count_15, fhv_dec_day_count_15, fhv_dec_eve_count_15, fhv_dec_afthrs_count_15]
June_2015 = [fhv_june_morn_count_15, fhv_june_day_count_15, fhv_june_eve_count_15, fhv_june_afthrs_count_15]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'June_2015': June_2015,
                   'Dec_2015': Dec_2015}, index=index)
df.plot.bar(rot=0)
plt.title("For Hire Vehicles in Manhattan")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
# Out:
# Text(0.5, 0, 'Time of Day')

# %% [markdown]
# ## High Volume For Hire Vehicles - June 2019

# %%
high_volume_2019_06 = "../clean_csvs/HighVol_june_2019.csv"
hv_june_2019_df = pd.read_csv(high_volume_2019_06)
hv_june_2019_df.head()
# Out:
#    Unnamed: 0 hvfhs_license_num dispatching_base_num      pickup_datetime  \
# 0          90            HV0004               B02800  2019-06-01 00:09:57
# 1         143            HV0003               B02869  2019-06-01 00:20:37
# 2         171            HV0003               B02884  2019-06-01 00:30:42
# 3         199            HV0003               B02764  2019-06-01 00:34:54
# 4         273            HV0003               B02835  2019-06-01 00:34:46
#
#       dropoff_datetime  PULocationID  DOLocationID pickup_date pickup_time  \
# 0  2019-06-01 00:16:41           237           263  2019-06-01    00:09:57
# 1  2019-06-01 00:37:38            45           263  2019-06-01    00:20:37
# 2  2019-06-01 00:41:14           170           263  2019-06-01    00:30:42
# 3  2019-06-01 00:39:28           263           236  2019-06-01    00:34:54
# 4  2019-06-01 01:18:08           179           263  2019-06-01    00:34:46
#
#   dropoff_date dropoff_time
# 0   2019-06-01     00:16:41
# ...

# %%
# High Volume for Hire Vehicles Pick-ups for June 2019
# Identify 4 different times of day and count the number of high volume for vehicle rides that occur in each 6 hour interval
# hv_june_2019_df

hv_morning_june_19_df = hv_june_2019_df.loc[(hv_june_2019_df['pickup_time'] > '05:00:00') & (hv_june_2019_df['pickup_time']<='11:00:00')]
hv_june_morn_count_19 = hv_morning_june_19_df.shape[0]

hv_day_june_19_df = hv_june_2019_df.loc[(hv_june_2019_df['pickup_time'] > '11:00:00') & (hv_june_2019_df['pickup_time']<='17:00:00')]
hv_june_day_count_19 = hv_day_june_19_df.shape[0]

hv_evening_june_19_df = hv_june_2019_df.loc[(hv_june_2019_df['pickup_time'] > '17:00:00') & (hv_june_2019_df['pickup_time']<='23:00:00')]
hv_june_eve_count_19 = hv_evening_june_19_df.shape[0]

hv_late_night_june_19_df = hv_june_2019_df.loc[(hv_june_2019_df['pickup_time'] > '23:00:00')]
hv_june_ln_count_19 = hv_late_night_june_19_df.shape[0]

hv_later_night_june_19_df = hv_june_2019_df.loc[(hv_june_2019_df['pickup_time'] <= '05:00:00')]
hv_june_lrn_count_19 = hv_later_night_june_19_df.shape[0]

hv_june_afthrs_count_19 = hv_june_lrn_count_19 + hv_june_ln_count_19

# %% [markdown]
# ## High Volume For Hire Vehicles - December 2019

# %%
high_volume_2019_12 = "../clean_csvs/HighVol_dec_2019.csv"
hv_dec_2019_df = pd.read_csv(high_volume_2019_12)
hv_dec_2019_df.head()
# Out:
#    Unnamed: 0 hvfhs_license_num dispatching_base_num      pickup_datetime  \
# 0           6            HV0003               B02764  2019-12-01 00:18:15
# 1           7            HV0003               B02764  2019-12-01 00:40:46
# 2         211            HV0005               B02510  2019-12-01 00:48:13
# 3         225            HV0003               B02876  2019-12-01 00:31:09
# 4         312            HV0003               B02880  2019-12-01 00:21:48
#
#       dropoff_datetime  PULocationID  DOLocationID pickup_date pickup_time  \
# 0  2019-12-01 00:38:07            25           263  2019-12-01    00:18:15
# 1  2019-12-01 00:52:38           263           226  2019-12-01    00:40:46
# 2  2019-12-01 01:08:21           200           263  2019-12-01    00:48:13
# 3  2019-12-01 00:49:02           263           166  2019-12-01    00:31:09
# 4  2019-12-01 00:27:19           263           141  2019-12-01    00:21:48
#
#   dropoff_date dropoff_time
# 0   2019-12-01     00:38:07
# ...

# %%
# High Volume for Hire Vehicles Pick-ups for December 2019
# Identify 4 different times of day and count the number of high volume for vehicle rides that occur in each 6 hour interval
# hv_dec_2019_df

hv_morning_dec_19_df = hv_dec_2019_df.loc[(hv_dec_2019_df['pickup_time'] > '05:00:00') & (hv_dec_2019_df['pickup_time']<='11:00:00')]
hv_dec_morn_count_19 = hv_morning_dec_19_df.shape[0]

hv_day_dec_19_df = hv_dec_2019_df.loc[(hv_dec_2019_df['pickup_time'] > '11:00:00') & (hv_dec_2019_df['pickup_time']<='17:00:00')]
hv_dec_day_count_19 = hv_day_dec_19_df.shape[0]

hv_evening_dec_19_df = hv_dec_2019_df.loc[(hv_dec_2019_df['pickup_time'] > '17:00:00') & (hv_dec_2019_df['pickup_time']<='23:00:00')]
hv_dec_eve_count_19 = hv_evening_dec_19_df.shape[0]

hv_late_night_dec_19_df = hv_dec_2019_df.loc[(hv_dec_2019_df['pickup_time'] > '23:00:00')]
hv_dec_ln_count_19 = hv_late_night_dec_19_df.shape[0]

hv_later_night_dec_19_df = hv_dec_2019_df.loc[(hv_dec_2019_df['pickup_time'] <= '05:00:00')]
hv_dec_lrn_count_19 = hv_later_night_dec_19_df.shape[0]

hv_dec_afthrs_count_19 = hv_dec_lrn_count_19 + hv_dec_ln_count_19

# %%
# Plot bar chart for high volume for hire vehicles in December & June of 2019

June_2019 = [hv_june_morn_count_19, hv_june_day_count_19, hv_june_eve_count_19, hv_june_afthrs_count_19]
Dec_2019 = [hv_dec_morn_count_19, hv_dec_day_count_19, hv_dec_eve_count_19, hv_dec_afthrs_count_19]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'June_2019': June_2019,
                   'Dec_2019': Dec_2019}, index=index)
df.plot.bar(rot=0)
plt.title("High Volume For Hire Vehicles in Manhattan")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
# Out:
# Text(0.5, 0, 'Time of Day')

# %% [markdown]
# ## Yellow Taxis - June 2019

# %%
yellow_taxi_2019_06 = "../clean_csvs/taxi_june_2019.csv"
yt_june_2019_df = pd.read_csv(yellow_taxi_2019_06)
yt_june_2019_df.head()
# Out:
#    Unnamed: 0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           1  2019-06-01 00:06:31   2019-06-01 00:06:52                1
# 1          78  2019-06-01 00:37:38   2019-06-01 00:41:39                1
# 2          92  2019-06-01 00:57:21   2019-06-01 01:12:09                2
# 3         128  2019-06-01 00:51:48   2019-06-01 00:59:28                1
# 4         141  2019-06-01 00:46:00   2019-06-01 00:48:17                1
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  fare_amount  \
# 0           0.00           1           262           263          2.5
# 1           0.60           1           237           263          5.0
# 2           3.10           1           230           263         12.5
# 3           1.73           1           141           263          8.0
# 4           0.80           1           263           141          4.5
#
#    tip_amount  total_amount pickup_date pickup_time dropoff_date dropoff_time
# ...

# %%
#yt_june_2019_df.dtypes

# %%
# Yellow Taxi Pick-ups for June 2019
# Identify 4 different times of day and count the number of taxi rides that occur in each 6 hour interval
#yt_dec_2019_df

yt_morning_june_19_df = yt_june_2019_df.loc[(yt_june_2019_df['pickup_time'] > '05:00:00') & (yt_june_2019_df['pickup_time']<='11:00:00')]
yt_june_morn_count_19 = yt_morning_june_19_df.shape[0]
#print(yt_june_morn_count_19)

yt_day_june_19_df = yt_june_2019_df.loc[(yt_june_2019_df['pickup_time'] > '11:00:00') & (yt_june_2019_df['pickup_time']<='17:00:00')]
yt_june_day_count_19 = yt_day_june_19_df.shape[0]
#print(yt_june_day_count_19)

yt_evening_june_19_df = yt_june_2019_df.loc[(yt_june_2019_df['pickup_time'] > '17:00:00') & (yt_june_2019_df['pickup_time']<='23:00:00')]
yt_june_eve_count_19 = yt_evening_june_19_df.shape[0]
#print(yt_june_eve_count_19)

yt_late_night_june_19_df = yt_june_2019_df.loc[(yt_june_2019_df['pickup_time'] > '23:00:00')]
yt_june_ln_count_19 = yt_late_night_june_19_df.shape[0]

yt_later_night_june_19_df = yt_june_2019_df.loc[(yt_june_2019_df['pickup_time'] <= '05:00:00')]
yt_june_lrn_count_19 = yt_later_night_june_19_df.shape[0]

yt_june_afthrs_count_19 = yt_june_lrn_count_19 + yt_june_ln_count_19
#print(yt_june_afthrs_count_19)

# %% [markdown]
# # Yellow Taxis - December 2019

# %%
yellow_taxi_2019_12 = "../clean_csvs/taxi_dec_2019.csv"
yt_dec_2019_df = pd.read_csv(yellow_taxi_2019_12)
yt_dec_2019_df.head()
# Out:
#    Unnamed: 0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          25  2019-12-01 00:10:13   2019-12-01 00:13:30              3.0
# 1         107  2019-12-01 00:08:57   2019-12-01 00:20:32              2.0
# 2         116  2019-12-01 00:19:30   2019-12-01 00:32:50              1.0
# 3         117  2019-12-01 00:02:30   2019-12-01 00:04:37              4.0
# 4         125  2019-12-01 00:36:40   2019-12-01 00:50:10              1.0
#
#    trip_distance  RatecodeID  PULocationID  DOLocationID  fare_amount  \
# 0           1.20         1.0           140           263          5.5
# 1           3.10         1.0            48           263         11.5
# 2           4.36         1.0           148           263         14.5
# 3           0.59         1.0           141           263          4.0
# 4           4.40         1.0           264           263         14.5
#
#    tip_amount  total_amount pickup_date pickup_time dropoff_date dropoff_time
# ...

# %%
# Yellow Taxi Pick-ups for December 2019
# Identify 4 different times of day and count the number of taxi rides that occur in each 6 hour interval
#yt_dec_2019_df

yt_morning_dec_19_df = yt_dec_2019_df.loc[(yt_dec_2019_df['pickup_time'] > '05:00:00') & (yt_dec_2019_df['pickup_time']<='11:00:00')]
yt_dec_morn_count_19 = yt_morning_dec_19_df.shape[0]
#print(yt_dec_morn_count_19)

yt_day_dec_19_df = yt_dec_2019_df.loc[(yt_dec_2019_df['pickup_time'] > '11:00:00') & (yt_dec_2019_df['pickup_time']<='17:00:00')]
yt_dec_day_count_19 = yt_day_dec_19_df.shape[0]
#print(yt_dec_day_count_19)

yt_evening_dec_19_df = yt_dec_2019_df.loc[(yt_dec_2019_df['pickup_time'] > '17:00:00') & (yt_dec_2019_df['pickup_time']<='23:00:00')]
yt_dec_eve_count_19 = yt_evening_dec_19_df.shape[0]
#print(yt_dec_eve_count_19)

yt_late_night_dec_19_df = yt_dec_2019_df.loc[(yt_dec_2019_df['pickup_time'] > '23:00:00')]
yt_dec_ln_count_19 = yt_late_night_dec_19_df.shape[0]


yt_later_night_dec_19_df = yt_dec_2019_df.loc[(yt_dec_2019_df['pickup_time'] <= '05:00:00')]
yt_dec_lrn_count_19 = yt_later_night_dec_19_df.shape[0]

yt_dec_afthrs_count_19 = yt_dec_lrn_count_19 + yt_dec_ln_count_19
#print(yt_dec_afthrs_count_19)

# %%
# Plot bar chart for yellow cabs in June of 2015 & 2019

June_2015 = [yt_june_morn_count_15, yt_june_day_count_15, yt_june_eve_count_15, yt_june_afthrs_count_15]
June_2019 = [yt_june_morn_count_19, yt_june_day_count_19, yt_june_eve_count_19, yt_june_afthrs_count_19]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'June_2015': June_2015,
                   'June_2019': June_2019}, index=index)
df.plot.bar(rot=0)
plt.title("Yellow Cabs in Manhattan")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
# Out:
# Text(0.5, 0, 'Time of Day')

# %%
# Plot bar chart for for hire vehicles in June of 2015 & 2019

June_2015 = [fhv_june_morn_count_15, fhv_june_day_count_15, fhv_june_eve_count_15, fhv_june_afthrs_count_15]
June_2019 = [hv_june_morn_count_19, hv_june_day_count_19, hv_june_eve_count_19, hv_june_afthrs_count_19]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'June_2015': June_2015,
                   'June_2019': June_2019}, index=index)
df.plot.bar(rot=0)
plt.title("For Hire Vehicles in Manhattan")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
# Out:
# Text(0.5, 0, 'Time of Day')

# %%
# Plot bar chart to compare yellow cabs & for hire vehicles in June of 2015

fhv_June_2015 = [fhv_june_morn_count_15, fhv_june_day_count_15, fhv_june_eve_count_15, fhv_june_afthrs_count_15]
yt_June_2015 = [yt_june_morn_count_15, yt_june_day_count_15, yt_june_eve_count_15, yt_june_afthrs_count_15]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'Taxis': yt_June_2015,
                   'For Hire': fhv_June_2015}, index=index)

df.plot.bar(rot=0)
plt.title("For Hire vs Taxis in Manhattan - June 2015")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")


# Plot bar chart to compare yellow cabs & for hire vehicles in December of 2015

fhv_Dec_2015 = [fhv_dec_morn_count_15, fhv_dec_day_count_15, fhv_dec_eve_count_15, fhv_dec_afthrs_count_15]
yt_Dec_2015 = [yt_dec_morn_count_15, yt_dec_day_count_15, yt_dec_eve_count_15, yt_dec_afthrs_count_15]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'Taxis': yt_Dec_2015,
                   'For Hire': fhv_Dec_2015}, index=index)


df.plot.bar(rot=0)
plt.title("For Hire vs Taxis in Manhattan - December 2015")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
# Out:
# Text(0.5, 0, 'Time of Day')

# %%
# Plot bar chart to compare yellow cabs & high frequency for hire vehicles in June of 2019

hv_June_2019 = [hv_june_morn_count_19, hv_june_day_count_19, hv_june_eve_count_19, hv_june_afthrs_count_19]
yt_June_2019 = [yt_june_morn_count_19, yt_june_day_count_19, yt_june_eve_count_19, yt_june_afthrs_count_19]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'Taxis': yt_June_2019,
                   'For Hire': hv_June_2019}, index=index)

df.plot.bar(rot=0)
plt.title("For Hire vs Taxis in Manhattan - June 2019")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
plt.axhline(y = 50000, color = '0', linestyle = 'dashed')


# Plot bar chart to compare yellow cabs & high frequency for hire vehicles in December of 2019

hv_Dec_2019 = [hv_dec_morn_count_19, hv_dec_day_count_19, hv_dec_eve_count_19, hv_dec_afthrs_count_19]
yt_Dec_2019 = [yt_dec_morn_count_19, yt_dec_day_count_19, yt_dec_eve_count_19, yt_dec_afthrs_count_19]
index = ["5am-11am", "11am-5pm", "5pm-11pm", "11pm-5am"]
df = pd.DataFrame({'Taxis': yt_Dec_2019,
                   'For Hire': hv_Dec_2019}, index=index)

df.plot.bar(rot=0)
plt.title("For Hire vs Taxis in Manhattan - December 2019")
plt.ylabel("Number of Pickups")
plt.xlabel("Time of Day")
plt.axhline(y = 50000, color = '0', linestyle = 'dashed')

# %%
#yt_dec_2019_df['tpep_pickup_datetime']= pd.to_datetime(yt_dec_2019_df['tpep_pickup_datetime'])
#yt_dec_2019_df.dtypes
#yt_june_2019_df.set_index("tpep_pickup_datetime", inplace = True)  

#Use between time to count rides in specific time windows.

#count_yt_dec_19_rows = yt_dec_2019_df.between_time('05:00:01','00:11:00').shape[0]
#count_yt_dec_19_rows

#yt_dec_2019_df.between_time('05:00:00','00:11:00')
